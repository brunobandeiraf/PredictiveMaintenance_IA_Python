# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Criar DataFrames com base no Dataset Dados_1

# %%
# Carregar os dados do arquivo .npy
dados = np.load('../../datasets/Classes.npy', allow_pickle=True)

# Converter os dados em um DataFrame pandas
classes = pd.DataFrame(dados)

# Alterar o nome da primeira coluna para "Classe"
classes = classes.rename(columns={classes.columns[0]: "Classe"})

# Exibir o DataFrame
print(classes)
# Out:
#          Classe
# 0      Classe D
# 1      Classe A
# 2      Classe A
# 3      Classe B
# 4      Classe D
# ...         ...
# 49995  Classe B
# 49996  Classe E
# 49997  Classe D
# 49998  Classe A
# 49999  Classe B
#
# [50000 rows x 1 columns]

# %%
# Carregar os dados .npy usando o NumPy
dados1_numpy = np.load('../../datasets/Dados_1.npy')

# Converter os dados para um DataFrame pandas
df_carregamento_1 = pd.DataFrame(dados1_numpy)

# %%
# Mostrar 5 primeiros registros do Dataframe
df_carregamento_1.head(5)
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.032906 -0.037456 -0.034082 -0.001968  0.084229  0.156574  0.128887
# 1  0.198619  0.178949  0.072092  0.083383  0.151363  0.108910 -0.099102
# 2 -0.000792  0.012913  0.017356  0.024251  0.022153  0.019270  0.017725
# 3 -0.086419 -0.112830 -0.124875 -0.029539 -0.067434 -0.077257  0.064067
# 4 -0.185975 -0.066973  0.042906  0.007640 -0.038686 -0.012729  0.111408
#
#         7         8         9    ...       191       192       193       194  \
# 0  0.042514 -0.036834 -0.013936  ... -0.099786 -0.080654 -0.070954 -0.003636
# 1 -0.195660 -0.125213  0.042914  ... -0.135897 -0.024512  0.103591  0.168580
# 2  0.013644  0.015150  0.020608  ...  0.016042  0.014681  0.017848  0.015588
# 3  0.075505  0.044812 -0.055143  ... -0.032053  0.002037  0.062153 -0.033044
# 4  0.104206  0.040331 -0.042868  ...  0.114014  0.089271  0.050639 -0.007533
#
#         195       196       197       198       199  200
# ...

# %%
# Mostrar 5 últimos registros
df_carregamento_1.tail(5)
# Out:
#             0         1         2         3         4         5         6    \
# 49995 -0.150609 -0.141931  0.006787  0.126504  0.074398  0.019470  0.138795
# 49996 -0.022837  0.044259  0.040861  0.020469 -0.054198  0.007702  0.018109
# 49997 -0.050631  0.045973  0.015404  0.095290  0.142208  0.157520  0.188304
# 49998 -0.161478 -0.102192 -0.025565  0.020177 -0.009493  0.078840  0.081992
# 49999  0.107004  0.018494 -0.015834  0.045719  0.294639  0.102430 -0.065973
#
#             7         8         9    ...       191       192       193  \
# 49995  0.177527  0.126558 -0.014036  ...  0.108879  0.124168  0.094821
# 49996  0.024812  0.109748  0.135744  ...  0.021784 -0.029078 -0.029286
# 49997  0.108703  0.065112  0.096858  ... -0.040792 -0.019485 -0.039486
# 49998  0.102500  0.147781  0.003428  ...  0.069363  0.180433  0.200979
# 49999 -0.111477  0.147781  0.040162  ... -0.099925 -0.149933 -0.021422
#
#             194       195       196       197       198       199  200
# ...

# %%
# Mostrar estrutura / schema do Dataframe
df_carregamento_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Columns: 201 entries, 0 to 200
# dtypes: float64(201)
# memory usage: 76.7 MB

# %%
# Unificando a Classe com o Dataframe 
df_dados_1 = pd.concat([classes, df_carregamento_1], axis=1)

print(df_dados_1)
# Out:
#          Classe         0         1         2         3         4         5  \
# 0      Classe D -0.032906 -0.037456 -0.034082 -0.001968  0.084229  0.156574
# 1      Classe A  0.198619  0.178949  0.072092  0.083383  0.151363  0.108910
# 2      Classe A -0.000792  0.012913  0.017356  0.024251  0.022153  0.019270
# 3      Classe B -0.086419 -0.112830 -0.124875 -0.029539 -0.067434 -0.077257
# 4      Classe D -0.185975 -0.066973  0.042906  0.007640 -0.038686 -0.012729
# ...         ...       ...       ...       ...       ...       ...       ...
# 49995  Classe B -0.150609 -0.141931  0.006787  0.126504  0.074398  0.019470
# 49996  Classe E -0.022837  0.044259  0.040861  0.020469 -0.054198  0.007702
# 49997  Classe D -0.050631  0.045973  0.015404  0.095290  0.142208  0.157520
# 49998  Classe A -0.161478 -0.102192 -0.025565  0.020177 -0.009493  0.078840
# 49999  Classe B  0.107004  0.018494 -0.015834  0.045719  0.294639  0.102430
#
# ...

# %%
# Mostrar estrutura / schema do Dataframe
df_dados_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Columns: 202 entries, Classe to 200
# dtypes: float64(201), object(1)
# memory usage: 77.1+ MB

# %% [markdown]
# # Transformação de Dados

# %%
pd.set_option('future.no_silent_downcasting', True)

# Mapear os valores para os números desejados
mapeamento = {'Classe A': 1, 'Classe B': 2, 'Classe C': 3, 'Classe D': 4, 'Classe E': 5}

# Substituir os valores na primeira coluna de acordo com o mapeamento
df_dados_1.iloc[:, 0] = df_dados_1.iloc[:, 0].replace(mapeamento)

# %%
# Mostrar 5 primeiros registros do Dataframe
df_dados_1.head(5)
# Out:
#   Classe         0         1         2         3         4         5  \
# 0      4 -0.032906 -0.037456 -0.034082 -0.001968  0.084229  0.156574
# 1      1  0.198619  0.178949  0.072092  0.083383  0.151363  0.108910
# 2      1 -0.000792  0.012913  0.017356  0.024251  0.022153  0.019270
# 3      2 -0.086419 -0.112830 -0.124875 -0.029539 -0.067434 -0.077257
# 4      4 -0.185975 -0.066973  0.042906  0.007640 -0.038686 -0.012729
#
#           6         7         8  ...       191       192       193       194  \
# 0  0.128887  0.042514 -0.036834  ... -0.099786 -0.080654 -0.070954 -0.003636
# 1 -0.099102 -0.195660 -0.125213  ... -0.135897 -0.024512  0.103591  0.168580
# 2  0.017725  0.013644  0.015150  ...  0.016042  0.014681  0.017848  0.015588
# 3  0.064067  0.075505  0.044812  ... -0.032053  0.002037  0.062153 -0.033044
# 4  0.111408  0.104206  0.040331  ...  0.114014  0.089271  0.050639 -0.007533
#
#         195       196       197       198       199  200
# ...

# %%
# Mostrar 5 últimos registros
df_dados_1.tail(5)
# Out:
#       Classe         0         1         2         3         4         5  \
# 49995      2 -0.150609 -0.141931  0.006787  0.126504  0.074398  0.019470
# 49996      5 -0.022837  0.044259  0.040861  0.020469 -0.054198  0.007702
# 49997      4 -0.050631  0.045973  0.015404  0.095290  0.142208  0.157520
# 49998      1 -0.161478 -0.102192 -0.025565  0.020177 -0.009493  0.078840
# 49999      2  0.107004  0.018494 -0.015834  0.045719  0.294639  0.102430
#
#               6         7         8  ...       191       192       193  \
# 49995  0.138795  0.177527  0.126558  ...  0.108879  0.124168  0.094821
# 49996  0.018109  0.024812  0.109748  ...  0.021784 -0.029078 -0.029286
# 49997  0.188304  0.108703  0.065112  ... -0.040792 -0.019485 -0.039486
# 49998  0.081992  0.102500  0.147781  ...  0.069363  0.180433  0.200979
# 49999 -0.065973 -0.111477  0.147781  ... -0.099925 -0.149933 -0.021422
#
#             194       195       196       197       198       199  200
# ...

# %%
# Removendo a última coluna do Dataframe
df_dados_1.drop(df_dados_1.columns[-1], axis=1, inplace=True)

# %%
df_dados_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Columns: 201 entries, Classe to 199
# dtypes: float64(200), object(1)
# memory usage: 76.7+ MB

# %% [markdown]
# # Detecção de Valores Ausentes

# %%
# Quantidade de colunas que possuem pelo menos 1 valor ausente NaN
df_dados_1.isna().any(axis=0).sum()
# Out:
# 0

# %%
# Detectar valores ausentes em todas as colunas do Dataset (Qtd)
df_dados_1.isna().sum()
# Out:
# Classe    0
# 0         0
# 1         0
# 2         0
# 3         0
#          ..
# 195       0
# 196       0
# 197       0
# 198       0
# 199       0
# Length: 201, dtype: int64

# %% [markdown]
# # Remover Valores Ausentes

# %% [markdown]
# # Análise dos Dados

# %%
# Adicionar o id no dataset 
# df_dados_1.insert(loc=0, value=11111, column=None)

# %%
# Correlação do Dataframe, segundo Pearson 
# df_dados_1.corr(method='pearson')

# %%
df_dados_1.head(5)
# Out:
#   Classe         0         1         2         3         4         5  \
# 0      4 -0.032906 -0.037456 -0.034082 -0.001968  0.084229  0.156574
# 1      1  0.198619  0.178949  0.072092  0.083383  0.151363  0.108910
# 2      1 -0.000792  0.012913  0.017356  0.024251  0.022153  0.019270
# 3      2 -0.086419 -0.112830 -0.124875 -0.029539 -0.067434 -0.077257
# 4      4 -0.185975 -0.066973  0.042906  0.007640 -0.038686 -0.012729
#
#           6         7         8  ...       190       191       192       193  \
# 0  0.128887  0.042514 -0.036834  ... -0.036180 -0.099786 -0.080654 -0.070954
# 1 -0.099102 -0.195660 -0.125213  ... -0.306607 -0.135897 -0.024512  0.103591
# 2  0.017725  0.013644  0.015150  ...  0.027556  0.016042  0.014681  0.017848
# 3  0.064067  0.075505  0.044812  ...  0.023029 -0.032053  0.002037  0.062153
# 4  0.111408  0.104206  0.040331  ...  0.074705  0.114014  0.089271  0.050639
#
#         194       195       196       197       198       199
# ...

# %%
# Retorna a quantidade de registros que possuem a classe A (1), B (2), C (3), D (4) e E (5)

#df_dados_1.groupby(df_dados_1.iloc[:, 0]).size().sort_values().plot.barh(figsize = (5,3))
contagem_por_classe = df_dados_1.groupby(df_dados_1.iloc[:, 0]).size().sort_values()
contagem_por_classe.index = ['Classe A', 'Classe B', 'Classe C', 'Classe D', 'Classe E']
contagem_por_classe.plot.barh(figsize=(5, 3))
# Out:
# <Axes: >

# %% [markdown]
# # Automatizando EDA

# %%
import sweetviz as sv

# %%
# SweetViz - Abrir no Jupyter Notebook
# Se você não precisa da análise de pares, defina pairwise_analysis como 'off'
sv_dados_report = sv.analyze(df_dados_1, pairwise_analysis='off')

# Se você precisa da análise de pares, defina pairwise_analysis como 'on'
#sv_dados_report = sv.analyze(df_dados_1, pairwise_analysis='on')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Feature: 199                                 |██████████| [100%]   01:15 -> (00:00 left)

# %%
# Sweetviz - HTML
sv_dados_report.show_html(filepath='./sweetviz/dados1/sweetviz_Off.html', open_browser=False, layout='widescreen')
# Out:
# Report ./report_dados.html was generated.

# %%
# # Sweetviz - Abaixo
sv_dados_report.show_notebook()

# %% [markdown]
# # Exportando Dataset - eda_dados_1.npy

# %%
# Adicionar o id no dataset 
df_dados_1.insert(loc=1, value=1, column='ID')

# %%
# Salvando o DataFrame em um arquivo CSV
df_dados_1.to_csv('../conjunto/datasets/eda_dados_1.csv', index=False)
