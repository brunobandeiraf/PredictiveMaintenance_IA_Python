# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Criar DataFrames com base no Dataset Dados_5

# %%
# Carregar os dados do arquivo .npy
dados = np.load('../../datasets/Classes.npy', allow_pickle=True)

# Converter os dados em um DataFrame pandas
classes = pd.DataFrame(dados)

# Alterar o nome da primeira coluna para "Classe"
classes = classes.rename(columns={classes.columns[0]: "Classe"})

# Exibir o DataFrame
print(classes)
# Out:
#          Classe
# 0      Classe D
# 1      Classe A
# 2      Classe A
# 3      Classe B
# 4      Classe D
# ...         ...
# 49995  Classe B
# 49996  Classe E
# 49997  Classe D
# 49998  Classe A
# 49999  Classe B
#
# [50000 rows x 1 columns]

# %%
# Carregar os dados .npy usando o NumPy
dados5_numpy = np.load('../../datasets/Dados_5.npy')

# Converter os dados para um DataFrame pandas
df_carregamento_5 = pd.DataFrame(dados5_numpy)

# %%
# Mostrar 5 primeiros registros do Dataframe
df_carregamento_5.head(5)
# Out:
#          0          1          2          3           4          5    \
# 0  20.881372  15.145424  72.027388  48.214406  131.643082  41.718371
# 1  -1.206457  46.549414  46.111607  10.361296   27.363958  23.396119
# 2  62.824083  68.291606  40.739371  89.487447   85.516643  13.587243
# 3  -7.094894  51.408032  76.682650   5.085699   22.564127  76.027758
# 4  14.008962  95.614914 -11.578788  42.905703   49.074270  26.468865
#
#          6           7           8          9    ...         190        191  \
# 0  77.190388  132.137176   85.425556  48.097219  ...  123.293161  56.924154
# 1  30.862030   55.051419   63.062865  38.094601  ...   27.373759  33.123615
# 2  91.161633   14.344760   18.180341  26.735392  ...   51.169306   5.996007
# 3  17.434208    3.158283   23.282799  22.444662  ...   -4.630175  38.254381
# 4  32.333575   26.889737  106.665714  76.073738  ...  106.132122  80.656916
#
#           192         193        194        195         196        197  \
# ...

# %%
# Mostrar 5 últimos registros
df_carregamento_5.tail(5)
# Out:
#               0          1          2          3          4          5    \
# 49995   54.279703  33.188985  99.085747  65.970407  36.502635  77.214711
# 49996   63.216018  -2.271451  56.004961  71.316767  80.002577  42.061986
# 49997   65.833098  39.942176  19.359819  -2.557807  64.279789  41.268713
# 49998   47.373926  82.291995  24.378955  49.286727  40.478231  31.073879
# 49999  104.021377  63.186675  38.893919  95.227093  45.782839  41.323191
#
#               6          7          8          9    ...        190  \
# 49995   82.623710  37.289715  74.371652  68.321238  ...  52.572778
# 49996    6.507342   9.822835  12.104164  45.486819  ...  35.429833
# 49997   92.095870  20.574753  29.783843  64.198265  ...  40.078331
# 49998  122.045263  16.903205  52.003456   7.796169  ...  39.512072
# 49999   30.860458  25.375961  64.771229  34.086171  ...  52.447263
#
#               191        192         193        194         195         196  \
# ...

# %%
# Mostrar estrutura / schema do Dataframe
df_carregamento_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Columns: 200 entries, 0 to 199
# dtypes: float64(200)
# memory usage: 76.3 MB

# %%
# Unificando a Classe com o Dataframe 
df_dados_5 = pd.concat([classes, df_carregamento_5], axis=1)
print(df_dados_5)
# Out:
#          Classe           0          1          2          3           4  \
# 0      Classe D   20.881372  15.145424  72.027388  48.214406  131.643082
# 1      Classe A   -1.206457  46.549414  46.111607  10.361296   27.363958
# 2      Classe A   62.824083  68.291606  40.739371  89.487447   85.516643
# 3      Classe B   -7.094894  51.408032  76.682650   5.085699   22.564127
# 4      Classe D   14.008962  95.614914 -11.578788  42.905703   49.074270
# ...         ...         ...        ...        ...        ...         ...
# 49995  Classe B   54.279703  33.188985  99.085747  65.970407   36.502635
# 49996  Classe E   63.216018  -2.271451  56.004961  71.316767   80.002577
# 49997  Classe D   65.833098  39.942176  19.359819  -2.557807   64.279789
# 49998  Classe A   47.373926  82.291995  24.378955  49.286727   40.478231
# 49999  Classe B  104.021377  63.186675  38.893919  95.227093   45.782839
#
#                5           6           7           8  ...         190  \
# ...

# %%
# Mostrar estrutura / schema do Dataframe
df_dados_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Columns: 201 entries, Classe to 199
# dtypes: float64(200), object(1)
# memory usage: 76.7+ MB

# %% [markdown]
# # Transformação de Dados

# %%
pd.set_option('future.no_silent_downcasting', True)

# Mapear os valores para os números desejados
mapeamento = {'Classe A': 1, 'Classe B': 2, 'Classe C': 3, 'Classe D': 4, 'Classe E': 5}

# Substituir os valores na primeira coluna de acordo com o mapeamento
df_dados_5.iloc[:, 0] = df_dados_5.iloc[:, 0].replace(mapeamento)

# %%
# Mostrar 5 primeiros registros do Dataframe
df_dados_5.head(5)
# Out:
#   Classe          0          1          2          3           4          5  \
# 0      4  20.881372  15.145424  72.027388  48.214406  131.643082  41.718371
# 1      1  -1.206457  46.549414  46.111607  10.361296   27.363958  23.396119
# 2      1  62.824083  68.291606  40.739371  89.487447   85.516643  13.587243
# 3      2  -7.094894  51.408032  76.682650   5.085699   22.564127  76.027758
# 4      4  14.008962  95.614914 -11.578788  42.905703   49.074270  26.468865
#
#            6           7           8  ...         190        191         192  \
# 0  77.190388  132.137176   85.425556  ...  123.293161  56.924154   87.385904
# 1  30.862030   55.051419   63.062865  ...   27.373759  33.123615   49.853440
# 2  91.161633   14.344760   18.180341  ...   51.169306   5.996007   21.488412
# 3  17.434208    3.158283   23.282799  ...   -4.630175  38.254381   96.444782
# 4  32.333575   26.889737  106.665714  ...  106.132122  80.656916  109.780935
#
# ...

# %%
# Mostrar 5 últimos registros
df_dados_5.tail(5)
# Out:
#       Classe           0          1          2          3          4  \
# 49995      2   54.279703  33.188985  99.085747  65.970407  36.502635
# 49996      5   63.216018  -2.271451  56.004961  71.316767  80.002577
# 49997      4   65.833098  39.942176  19.359819  -2.557807  64.279789
# 49998      1   47.373926  82.291995  24.378955  49.286727  40.478231
# 49999      2  104.021377  63.186675  38.893919  95.227093  45.782839
#
#                5           6          7          8  ...        190  \
# 49995  77.214711   82.623710  37.289715  74.371652  ...  52.572778
# 49996  42.061986    6.507342   9.822835  12.104164  ...  35.429833
# 49997  41.268713   92.095870  20.574753  29.783843  ...  40.078331
# 49998  31.073879  122.045263  16.903205  52.003456  ...  39.512072
# 49999  41.323191   30.860458  25.375961  64.771229  ...  52.447263
#
#               191        192         193        194         195         196  \
# ...

# %% [markdown]
# # Detecção de Valores Ausentes

# %%
# Quantidade de colunas que possuem pelo menos 1 valor ausente NaN
df_dados_5.isna().any(axis=0).sum()
# Out:
# 200

# %%
# Detectar valores ausentes em todas as colunas do Dataset (Qtd)
df_dados_5.isna().sum()
# Out:
# Classe       0
# 0         1240
# 1         1207
# 2         1189
# 3         1231
#           ...
# 195       1242
# 196       1231
# 197       1214
# 198       1190
# 199       1242
# Length: 201, dtype: int64

# %% [markdown]
# # Remover Valores Ausentes

# %%
# Remover linhas com TODOS os valores ausentes das colunas
df_dados_5.dropna(axis=0, how='all', inplace=True)

# %%
# Remover linhas com algum valor ausente nas colunas
df_dados_5.dropna(axis=0, inplace=True)

# %%
df_dados_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30308 entries, 0 to 49995
# Columns: 201 entries, Classe to 199
# dtypes: float64(200), object(1)
# memory usage: 46.7+ MB

# %%
# Quantidade de colunas que possuem pelo menos 1 valor ausente NaN
df_dados_5.isna().any(axis=0).sum()
# Out:
# 0

# %% [markdown]
# # Exportando Dataset - eda_dados_5.npy

# %%
# Adicionar o id no dataset 
df_dados_5.insert(loc=1, value=5, column='ID')

# %%
# Salvando o DataFrame em um arquivo CSV
df_dados_5.to_csv('../conjunto/datasets/eda_dados_5.csv', index=False)
